# %% [markdown]
# # py-sas-studio-custom-steps
#
# ### This notebook walks you through the main operations offered by the [py-sas-studio-custom-steps](https://pypi.org/project/py-sas-studio-custom-steps/) package which helps you programmatically create and modify a SAS Studio Custom Step.

# %% [markdown]
# ### Imports
#
# ##### Assuming you have installed py-sas-studio-custom-steps in a virtual environment for testing.

# %%
from py_sas_studio_custom_steps import CustomStep
import os

# %% [markdown]
# ### Set path to folder containing example steps and test outputs
#
# ##### Most of these are part of this repository and an open-source SAS repository, SAS Studio Custom Steps at https://github.com/sassoftware/sas-studio-custom-steps

# %%
test_path = os.path.join(os.getcwd(),"..","tests")
existing_step = os.path.join(test_path,"DuckDB - Extract Parquet Metadata.step")
extracted_sas_file_local_name = os.path.join(test_path,"DuckDB - Extract Parquet Metadata.sas")
extracted_ui_local_name = os.path.join(test_path,"DuckDB - Extract Parquet Metadata components.json")

existing_step_on_gh = "https://github.com/sassoftware/sas-studio-custom-steps/blob/main/DuckDB%20-%20Aggregate%20Parquets/DuckDB%20-%20Aggregate%20Parquets.step"
extracted_sas_file_gh_name = os.path.join(test_path,"DuckDB - Aggregate Parquets.sas")
extracted_ui_gh_name = os.path.join(test_path,"DuckDB - Aggregate Parquets components.json")

example_sas_code = os.path.join(test_path,"example_sas_code.sas")
example_ui_config = os.path.join(test_path,"example_components.json")

example_README_file = os.path.join(test_path,"README.md")

# %% [markdown]
# ### Step 1: Create a Custom Step instance

# %%
# A new custom step object.  The __dict__ representation shows its structure. 
cs = CustomStep()
print(type(cs))
print("-----")
print(cs.__dict__)
# Out:
# <class 'py_sas_studio_custom_steps.custom_step.CustomStep'>
# -----
# {'name': 'Auto_Generated_14e557ed-e3e7-4fbf-84f0-80707aa3a732', 'creationTimeStamp': None, 'modifiedTimeStamp': None, 'createdBy': None, 'modifiedBy': None, 'displayName': None, 'localDisplayName': None, 'properties': None, 'links': None, 'metadataVersion': None, 'version': None, 'type': 'code', 'flowMetadata': None, 'ui': '{"showPageContentOnly": true, "pages": []}', 'templates': {'SAS': ''}}

# %% [markdown]
# #### Alternatively, create an instance based on an existing custom step

# %%
# This custom step exists locally
cs_existing = CustomStep(existing_step)
cs_existing.name
# Out:
# 'DuckDB - Extract Parquet Metadata.step'

# %%
# This custom step exists on GitHub and is now contained in the cs_existing custom step object.
cs_existing_gh = CustomStep(existing_step_on_gh)
cs_existing_gh.name
# Out:
# 'DuckDB - Aggregate Parquets.step'

# %% [markdown]
# ### Let's extract the SAS program out of a custom step object

# %%
# From our empty custom step
cs.extract_sas_program()
# Out:
# ''

# %%
# From our custom step based on a step from the GitHub repo
cs_existing_gh.extract_sas_program()
# Out:
# '/* SAS templated code goes here */\n\n/* -------------------------------------------------------------------------------------------*\n   DuckDB - Aggregate Parquets - Version 1.3.0\n\n   This program dynamically builds a DuckDB SQL aggregation query and\n   pushes it down to Duck DB through the SAS/ACCESS Interface to Duck DB.\n   \n   This version refactored to follow the structural patterns, macro usage and\n   verbose commenting style used by the "LLM - Azure OpenAI In-context Learning.sas"\n   program while preserving the original purpose and logic.\n\n   Author: Sundaresh Sankaran (original)\n   Refactor: Polished after AI-assisted automation\n   Version: 1.3.0 (2026-02-03)\n*-------------------------------------------------------------------------------------------- */\n\n/* -------------------------------------------------------------------------------------------*\n    User Parameters\n    \n    The parameters below allow customization of the aggregation operation,\n    including the input file path, aggregation functions, columns to aggregate,\n    grouping columns, and output table.\n    \n    Users can modify these parameters to suit their specific data and analysis needs.\n* -------------------------------------------------------------------------------------------- */\n\n/* Input option: \'single\' for a single parquet file, \'multiple\' for all parquet files in a folder */\n/* %let input_option=single; */\n\n/*  Directory or prefix containing parquet files  */\n/* %let parquet_file_path=sasserver:/mnt/viya-share/data/parquet-test/ss-new/parquet-test/HMEQ_WITH_CUST.parquet; */\n\n \n\n/* Aggregation function list: define count then each function name macro */\n/* %let function_name_count=4; */\n/* %let function_name_1=AVG; */\n/* %let function_name_2=SUM; */\n/* %let function_name_3=STDDEV; */\n/* %let function_name_4=COUNT; */\n\n/* Comma-separated list of columns to aggregate and group-by columns (space or comma separated OK)  */\n/* %let agg_columns=DELINQ DEBTINC;                    */\n/* %let group_by_columns= ;                  */\n\n/* Where clause to filter parquet data before aggregation (optional) */\n/* %let where_clause=       BAD=1; */\n\n/*  Output table assigned to the Duck DB engine. Provide libname-qualified name if desired.  */\n/* %let output_table=dukonce.TABLE_NUM_AGGS_DD; */\n\n\n\n\n/* -----------------------------------------------------------------------------------------*\n   Macros\n\n   The macros below follow the structural conventions used in prior custom steps by author:\n\n   - small utility macros for runtime triggers and error flags\n   - a focused macro to build SQL strings and one to execute the Duck DB query\n*------------------------------------------------------------------------------------------*/\n\n/* -------------------------------------------------------------------------------------------* \n   Macro to initialize a run-time trigger global macro variable to run SAS Studio Custom Steps. \n   A value of 1 (the default) enables this custom step to run.  A value of 0 (provided by \n   upstream code) sets this to disabled.\n\n   Input:\n   1. triggerName: The name of the runtime trigger you wish to create. Ensure you provide a \n      unique value to this parameter since it will be declared as a global variable.\n\n   Output:\n   2. &triggerName : A global variable which takes the name provided to triggerName.\n*-------------------------------------------------------------------------------------------- */\n\n%macro _create_runtime_trigger(triggerName);\n   %global &triggerName.;\n   %if %sysevalf(%superq(&triggerName.)=, boolean)  %then %do;\n      %put NOTE: Trigger macro variable &triggerName. does not exist. Creating it now.;\n      %let &triggerName.=1;\n   %end;\n%mend _create_runtime_trigger;\n\n\n/* -----------------------------------------------------------------------------------------* \n   Macro to create an error flag for capture during code execution.\n\n   ...

# %%
# Example of writing the extracted sas program to a new local SAS program file

with open(extracted_sas_file_local_name,"w",encoding="utf-8") as f:
    f.write(cs_existing.extract_sas_program())

# %% [markdown]
# ### Let's now extract the UI (a JSON structure) from the custom step object

# %%
# From our empty custom step
cs.extract_ui()
# Out:
# '{"showPageContentOnly": true, "pages": []}'

# %%
# From our object based on a local custom step
cs_existing.extract_ui()
# Out:
# '{"showPageContentOnly": true, "pages": [{"id": "params", "type": "page", "label": "Parameters", "children": [{"id": "text_page_extract_metadata", "type": "text", "text": "Parameters related to extraction of parquet metadata", "visible": ""}, {"id": "section_input_params", "type": "section", "label": "Source Parameters", "open": true, "children": [{"id": "input_option", "type": "radiogroup", "label": "Select your input type:", "items": [{"value": "single", "label": "Single parquet file"}, {"value": "multiple", "label": "Multiple parquet files in a folder"}], "visible": ""}, {"id": "parquet_file_path", "type": "path", "label": "Enter path to parquet file (should be located on the SAS server):", "pathtype": "file", "placeholder": "", "required": false, "visible": ["$input_option", "=", "single"], "enabled": ["$input_option", "=", "single"]}, {"id": "parquet_path", "type": "path", "label": "Enter path to folder containing parquet files (should be located on the SAS server):", "pathtype": "folder", "placeholder": "", "required": false, "visible": ["$input_option", "=", "multiple"], "enabled": ["$input_option", "=", "multiple"]}]}, {"id": "section1", "type": "section", "label": "Target Parameters", "open": true, "children": [{"id": "load_cas", "type": "checkbox", "label": "Load output to SAS Cloud Analytics Services (CAS)", "visible": ""}, {"id": "load_cas_text", "type": "text", "text": "If checked, the output table is loaded to CAS for visualisation. The default target table is PARQUET_METADATA in PUBLIC caslib (user can change this).\\n\\n", "visible": "", "indent": 1}, {"id": "target_caslib", "type": "textfield", "label": "Target CAS library name:", "placeholder": "PUBLIC", "required": false, "visible": ["$load_cas", "=", true], "enabled": ["$load_cas", "=", true], "indent": 1}, {"id": "target_tblname", "type": "textfield", "label": "Target CAS table name:", "placeholder": "PARQUET_METADATA", "required": false, "visible": ["$load_cas", "=", true], "enabled": ["$load_cas", "=", true], "indent": 1}, {"id": "output_table", "type": "outputtable", "label": "Output table (preferably a data set backed by a DuckDB libname)", "required": true, "placeholder": "", "visible": ""}]}]}, {"id": "page_copy_file", "type": "page", "label": "Copy File", "children": [{"id": "text_page_copy_file", "type": "text", "text": "Parameters to copy input file to a new parquet file with new metadata specifications (available only if a single parquet file is selected).", "visible": ""}, {"id": "write_parquet", "type": "checkbox", "label": "Write new parquet file (for single parquet files only) and specify metadata options ", "visible": ["$input_option", "=", "single"], "enabled": ["$input_option", "=", "single"]}, {"id": "section_parquet_writer", "type": "section", "label": "Parquet Writer Specifications", "open": true, "visible": [["$write_parquet", "=", true], "&", ["$input_option", "=", "single"]], "enabled": [["$write_parquet", "=", true], "&", ["$input_option", "=", "single"]], "children": [{"id": "metadata_option_tbl", "type": "optiontable", "label": "Specify metadata options:", "required": false, "tabletype": "authorboth", "initialrowcount": 1, "min": null, "max": null, "showcolumnlabels": true, "columns": [{"id": "ROW_GROUP_SIZE", "type": "numberfield", "required": false, "placeholder": "", "value": 122880, "integer": true, "max": null, "min": 2048, "excludemax": false, "excludemin": false, "label": "ROW_GROUP_SIZE"}, {"id": "ROW_GROUP_SIZE_BYTES", "type": "textfield", "label": "ROW_GROUP_SIZE_BYTES", "placeholder": "", "required": false, "value": "\'512MB\'"}, {"id": "ROW_GROUPS_PER_FILE", "type": "numberfield", "required": false, "label": "ROW_GROUPS_PER_FILE", "placeholder": "", "value": 8, "integer": true, "max": null, "min": 8, "excludemax": false, "excludemin": false}, {"id": "COMPRESSION", "type": "dropdown", "label": "COMPRESSION", "placeholder": "", "required": false, "value": {"value": "\'ZSTD\'", "label": "ZSTD"}, "items": [{"value": "\'SNA ...

# %%
# Example of writing the extracted UI to a new local JSON file

with open(extracted_ui_local_name,"w",encoding="utf-8") as f:
    f.write(cs_existing.extract_ui())

# %% [markdown]
# ### You can even extract the SAS program and UI from a custom step in a GitHub repository
# ##### The "empty" cs CustomStep object you created earlier serves the purpose of a via media

# %%
# TEst of extract sas program from GitHub repo

with open(extracted_sas_file_gh_name,"w",encoding="utf-8") as f:
    f.write(cs.extract_sas_program(existing_step_on_gh))

# TEst of extract UI from GitHub repo

with open(extracted_ui_gh_name,"w",encoding="utf-8") as f:
    f.write(cs.extract_ui(existing_step_on_gh))

# %% [markdown]
# ### Now, let's add a SAS program

# %%
# Test of attach_sas_program
cs = CustomStep()
rc = cs.attach_sas_program(example_sas_code)

print(rc)
print("=============")
print(cs.__dict__)
# Out:
# Custom step object updated with SAS program template from /Users/sinsrn/current_projects/py-sas-studio-custom-steps/scripts/../tests/example_sas_code.sas
# =============
# {'name': 'Auto_Generated_2e421a80-d964-4c26-9c7f-7299092079a8', 'creationTimeStamp': None, 'modifiedTimeStamp': None, 'createdBy': None, 'modifiedBy': None, 'displayName': None, 'localDisplayName': None, 'properties': None, 'links': None, 'metadataVersion': None, 'version': None, 'type': 'code', 'flowMetadata': None, 'ui': '{"showPageContentOnly": true, "pages": []}', 'templates': {'SAS': 'title "This is meant to show an example of SAS code that can be used in the tests";\nproc print data=sashelp.cars (obs=10);\nrun;\n'}}

# %% [markdown]
# ### Let's also attach a UI

# %%
# Test of attach_ui

rc = cs.attach_ui(ui_json_file= example_ui_config)

print(rc)
print("=============")
print(cs.__dict__)
# Out:
# Custom step object updated with UI configuration from /Users/sinsrn/current_projects/py-sas-studio-custom-steps/scripts/../tests/example_components.json
# =============
# {'name': 'Auto_Generated_2e421a80-d964-4c26-9c7f-7299092079a8', 'creationTimeStamp': None, 'modifiedTimeStamp': None, 'createdBy': None, 'modifiedBy': None, 'displayName': None, 'localDisplayName': None, 'properties': None, 'links': None, 'metadataVersion': None, 'version': None, 'type': 'code', 'flowMetadata': None, 'ui': '{"showPageContentOnly": true, "pages": [{"id": "page1_cars", "label": "Print CARS data", "type": "page", "children": [{"id": "input_table", "type": "inputtable", "label": "Select input table:", "required": false, "placeholder": "", "visible": "", "filter": false}, {"id": "input_table_columns", "type": "columnselector", "label": "Select columns:", "include": null, "order": false, "columntype": "a", "max": null, "min": null, "visible": "", "table": "input_table"}, {"id": "sample_text", "type": "text", "text": "Now select number of observations to display.", "visible": ""}, {"id": "text_field", "type": "nbr_obs", "label": "Example of a text field:", "placeholder": "", "required": false, "visible": ""}]}]}', 'templates': {'SAS': 'title "This is meant to show an example of SAS code that can be used in the tests";\nproc print data=sashelp.cars (obs=10);\nrun;\n'}}

# %% [markdown]
# ### Let's start documenting this step.  Add an About Page

# %%
rc = cs.add_about_page()

print(rc)
print("=============")
print(cs.__dict__)
# Out:
# About page added to the UI.
# =============
# {'name': 'Auto_Generated_2e421a80-d964-4c26-9c7f-7299092079a8', 'creationTimeStamp': None, 'modifiedTimeStamp': None, 'createdBy': None, 'modifiedBy': None, 'displayName': None, 'localDisplayName': None, 'properties': None, 'links': None, 'metadataVersion': None, 'version': None, 'type': 'code', 'flowMetadata': None, 'ui': '{"showPageContentOnly": true, "pages": [{"id": "page1_cars", "label": "Print CARS data", "type": "page", "children": [{"id": "input_table", "type": "inputtable", "label": "Select input table:", "required": false, "placeholder": "", "visible": "", "filter": false}, {"id": "input_table_columns", "type": "columnselector", "label": "Select columns:", "include": null, "order": false, "columntype": "a", "max": null, "min": null, "visible": "", "table": "input_table"}, {"id": "sample_text", "type": "text", "text": "Now select number of observations to display.", "visible": ""}, {"id": "text_field", "type": "nbr_obs", "label": "Example of a text field:", "placeholder": "", "required": false, "visible": ""}]}, {"id": "about", "type": "page", "label": "About", "children": [{"id": "section_about_intro", "type": "section", "label": "Provide Title of your custom step here", "open": true, "visible": "", "children": [{"id": "section_about_intro_text", "type": "text", "text": "Provide a brief description of your custom step here. This custom step ...", "visible": ""}, {"id": "section_about_parameters", "type": "section", "label": "Parameters", "open": false, "visible": "", "children": [{"id": "section_about_parameters_input", "type": "section", "label": "Input Parameters", "open": true, "children": [{"id": "section_about_parameters_input_text", "type": "text", "text": "List your input parameters here as a numeric or bulleted list, separated by line breaks. For example: \\n 1. input parameter 1 (input port, required): description\\n 2. input parameter 2...", "visible": ""}]}, {"id": "section_about_parameters_output", "type": "section", "label": "Output specification", "open": true, "visible": "", "children": [{"id": "section_about_parameters_output_text", "type": "text", "text": "List your input parameters here as a numeric or bulleted list, separated by line breaks. For example: \\n 1. input parameter 1 (input port, required): description\\n 2. input parameter 2... ", "visible": ""}]}]}, {"id": "section_references", "type": "section", "label": "References", "open": false, "children": [{"id": "references_text", "type": "text", "text": "Insert a bulleted or number list of references here."}]}, {"id": "section_about_version", "type": "section", "label": "About this step", "open": true, "children": [{"id": "version_text", "type": "text", "text": "Version: 0.1.0 (DDMONYYYY)\\nContact: Firstname Lastname (Firstname.Lastname@company.com)"}]}]}]}]}', 'templates': {'SAS': 'title "This is meant to show an example of SAS code that can be used in the tests";\nproc print data=sashelp.cars (obs=10);\nrun;\n'}}

# %%
# GEnerate a README from this custom step
user_prompt = """
Generate a README file with very short description of what this step does.  Affix a version number in semantic versioning (based on step's UI config) and note that 
the author's name is Sundaresh Sankaran (sundaresh.sankaran@sas.com). Use today's date for creation.
"""
cs.generate_readme(user_prompt, example_README_file)
# Out:
# 'README file generated at /Users/sinsrn/current_projects/py-sas-studio-custom-steps/scripts/../tests/README.md'

# %%
# Test of get_pages

cs.get_pages()
# Out:
# [{'id': 'page1_cars',
#   'label': 'Print CARS data',
#   'type': 'page',
#   'children': [{'id': 'input_table',
#     'type': 'inputtable',
#     'label': 'Select input table:',
#     'required': False,
#     'placeholder': '',
#     'visible': '',
#     'filter': False},
#    {'id': 'input_table_columns',
#     'type': 'columnselector',
#     'label': 'Select columns:',
#     'include': None,
#     'order': False,
#     'columntype': 'a',
#     'max': None,
#     'min': None,
#     'visible': '',
#     'table': 'input_table'},
#    {'id': 'sample_text',
#     'type': 'text',
#     'text': 'Now select number of observations to display.',
#     'visible': ''},
#    {'id': 'text_field',
#     'type': 'nbr_obs',
#     'label': 'Example of a text field:',
#     'placeholder': '',
#     'required': False,
#     'visible': ''}]},
#  {'id': 'about',
#   'type': 'page',
#   'label': 'About',
#   'children': [{'id': 'section_about_intro',
#     'type': 'section',
#     'label': 'Provide Title of your custom step here',
#     'open': True,
#     'visible': '',
#     'children': [{'id': 'section_about_intro_text',
#       'type': 'text',
#       'text': 'Provide a brief description of your custom step here. This custom step ...',
#       'visible': ''},
#      {'id': 'section_about_parameters',
#       'type': 'section',
#       'label': 'Parameters',
#       'open': False,
#       'visible': '',
#       'children': [{'id': 'section_about_parameters_input',
#         'type': 'section',
#         'label': 'Input Parameters',
#         'open': True,
#         'children': [{'id': 'section_about_parameters_input_text',
#           'type': 'text',
#           'text': 'List your input parameters here as a numeric or bulleted list, separated by line breaks. For example: \n 1. input parameter 1 (input port, required): description\n 2. input parameter 2...',
#           'visible': ''}]},
#        {'id': 'section_about_parameters_output',
#         'type': 'section',
#         'label': 'Output specification',
#         'open': True,
#         'visible': '',
#         'children': [{'id': 'section_about_parameters_output_text',
#           'type': 'text',
#           'text': 'List your input parameters here as a numeric or bulleted list, separated by line breaks. For example: \n 1. input parameter 1 (input port, required): description\n 2. input parameter 2... ',
#           'visible': ''}]}]},
#      {'id': 'section_references',
#       'type': 'section',
#       'label': 'References',
#       'open': False,
#       'children': [{'id': 'references_text',
#         'type': 'text',
#         'text': 'Insert a bulleted or number list of references here.'}]},
#      {'id': 'section_about_version',
#       'type': 'section',
#       'label': 'About this step',
#       'open': True,
#       'children': [{'id': 'version_text',
#         'type': 'text',
#         'text': 'Version: 0.1.0 (DDMONYYYY)\nContact: Firstname Lastname (Firstname.Lastname@company.com)'}]}]}]}]

# %%
cs.list_keys()
# Out:
# name
# creationTimeStamp
# modifiedTimeStamp
# createdBy
# modifiedBy
# displayName
# localDisplayName
# properties
# links
# metadataVersion
# version
# type
# flowMetadata
# ui
# templates
# ['name',
#  'creationTimeStamp',
#  'modifiedTimeStamp',
#  'createdBy',
#  'modifiedBy',
#  'displayName',
#  'localDisplayName',
#  'properties',
#  'links',
#  'metadataVersion',
#  'version',
#  'type',
#  'flowMetadata',
#  'ui',
#  'templates']

# %%
cs.add_about_page()
# Out:
# 'About page already exists in the UI.'

# %%
cs_new = CustomStep()
rc1 = cs_new.add_starter_page()
rc2 = cs_new.add_about_page()

print(rc1)
print(rc2)
# Out:
# Starter page added to the UI.
# About page added to the UI.

# %%
prompt = """
I want to create a custom step which gives me a simple calculator.  I get to enter 2 numbers, and then ask for either an add, subtract, divide or multiply function.
"""

cs_new.create_sas_program(prompt)
# Out:
# 'Program generated and attached to the custom step object successfully.'

# %%
cs_new.templates['SAS']
# Out:
# '/* Define macro variables for custom step inputs */\n%let num1 = ;          /* First numeric value */\n%let num2 = ;          /* Second numeric value */\n%let operation = ;     /* Calculation function: ADD, SUBTRACT, MULTIPLY, or DIVIDE */\n\n/* Perform the calculation and store the result */\ndata work.calculator_result;\n    /* Define variables and length */\n    length Operation $10 Error_Message $100;\n    \n    /* Assign inputs to dataset variables */\n    Num1 = &num1.;\n    Num2 = &num2.;\n    Operation = upcase("&operation.");\n    Result = .;\n    Error_Message = "";\n\n    /* Determine operation and calculate result */\n    select (Operation);\n        when (\'ADD\')      Result = Num1 + Num2;\n        when (\'SUBTRACT\') Result = Num1 - Num2;\n        when (\'MULTIPLY\') Result = Num1 * Num2;\n        when (\'DIVIDE\') do;\n            if Num2 = 0 then do;\n                Error_Message = "Error: Division by zero is undefined.";\n                put "ERROR: " Error_Message;\n            end;\n            else do;\n                Result = Num1 / Num2;\n            end;\n        end;\n        otherwise do;\n            Error_Message = "Error: Invalid operation specified. Choose ADD, SUBTRACT, MULTIPLY, or DIVIDE.";\n            put "ERROR: " Error_Message;\n        end;\n    end;\nrun;\n\n/* Display the result in the SAS Studio Results tab */\ntitle "Calculator Output";\nproc print data=work.calculator_result noobs;\n    var Num1 Operation Num2 Result Error_Message;\nrun;\ntitle;'

# %%
cs_new.create_ui(prompt)
# Out:
# 'UI configuration generated and attached to the custom step object successfully.'

# %%
cs_new.ui
# Out:
# '{\n  "showPageContentOnly": true,\n  "pages": [\n    {\n      "id": "page1",\n      "label": "Simple Calculator",\n      "type": "page",\n      "children": [\n        {\n          "id": "num1",\n          "type": "numfield",\n          "label": "First Number:",\n          "required": true,\n          "placeholder": "Enter first number"\n        },\n        {\n          "id": "num2",\n          "type": "numfield",\n          "label": "Second Number:",\n          "required": true,\n          "placeholder": "Enter second number"\n        },\n        {\n          "id": "operation",\n          "type": "dropdown",\n          "label": "Choose Operation:",\n          "required": true,\n          "items": [\n            {\n              "value": "ADD",\n              "label": "Add"\n            },\n            {\n              "value": "SUBTRACT",\n              "label": "Subtract"\n            },\n            {\n              "value": "MULTIPLY",\n              "label": "Multiply"\n            },\n            {\n              "value": "DIVIDE",\n              "label": "Divide"\n            }\n          ]\n        }\n      ]\n    }\n  ],\n  "syntaxversion": "1.3.0",\n  "values": {\n    "num1": null,\n    "num2": null,\n    "operation": {\n      "value": "ADD",\n      "label": "Add"\n    }\n  }\n}'
